# %% [markdown]
# # Playground for Association Rule Learning slides
#
# - Stephen W. Thomas
# - Used for MMA 869, MMAI 869, and GMMA 869

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2020-10-05 13:32:06.144238

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Example of converting lists into a dataframe

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df1 = pd.DataFrame(te_ary, columns=te.columns_)
df1
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %% [markdown]
# # Read in Data

# %%
df = pd.read_csv('../data/groceries.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9835 entries, 0 to 9834
# Columns: 169 entries, frankfurter to bags
# dtypes: bool(169)
# memory usage: 1.6 MB

# %%
df.head()
# Out:
#    frankfurter  sausage  liver loaf    ham   meat  finished products  \
# 0        False    False       False  False  False              False
# 1        False    False       False  False  False              False
# 2        False    False       False  False  False              False
# 3        False    False       False  False  False              False
# 4        False    False       False  False  False              False
#
#    organic sausage  chicken  turkey   pork  ...  candles  light bulbs  \
# 0            False    False   False  False  ...    False        False
# 1            False    False   False  False  ...    False        False
# 2            False    False   False  False  ...    False        False
# 3            False    False   False  False  ...    False        False
# 4            False    False   False  False  ...    False        False
#
#    sound storage medium  newspapers  photo/film  pot plants  \
# 0                 False       False       False       False
# 1                 False       False       False       False
# 2                 False       False       False       False
# 3                 False       False       False       False
# 4                 False       False       False       False
#
#    flower soil/fertilizer  flower (seeds)  shopping bags   bags
# 0                   False           False          False  False
# 1                   False           False          False  False
# 2                   False           False          False  False
# 3                   False           False          False  False
# 4                   False           False          False  False
#
# [5 rows x 169 columns]

# %%
from mlxtend.frequent_patterns import apriori

# %time frequent_itemsets = apriori(df, min_support=0.001, use_colnames=True)
# Out:
# Wall time: 17 s

# %%
frequent_itemsets.head(10)
# Out:
#     support             itemsets
# 0  0.058973        (frankfurter)
# 1  0.093950            (sausage)
# 2  0.005084         (liver loaf)
# 3  0.026029                (ham)
# 4  0.025826               (meat)
# 5  0.006507  (finished products)
# 6  0.002237    (organic sausage)
# 7  0.042908            (chicken)
# 8  0.008134             (turkey)
# 9  0.057651               (pork)

# %%
frequent_itemsets.tail(10)
# Out:
#         support                                           itemsets
# 13482  0.001118  (other vegetables, root vegetables, whole milk...
# 13483  0.001423  (other vegetables, root vegetables, whole milk...
# 13484  0.001017  (other vegetables, root vegetables, whole milk...
# 13485  0.001322  (other vegetables, pip fruit, root vegetables,...
# 13486  0.001118  (other vegetables, root vegetables, whole milk...
# 13487  0.001118  (other vegetables, root vegetables, whole milk...
# 13488  0.001322  (other vegetables, root vegetables, whole milk...
# 13489  0.001017  (other vegetables, oil, root vegetables, whole...
# 13490  0.001118  (other vegetables, root vegetables, whole milk...
# 13491  0.001017  (other vegetables, domestic eggs, whole milk, ...

# %%
frequent_itemsets.sort_values(by=['support'], ascending=False).head()
# Out:
#      support            itemsets
# 24  0.255516        (whole milk)
# 22  0.193493  (other vegetables)
# 53  0.183935        (rolls/buns)
# 99  0.174377              (soda)
# 29  0.139502            (yogurt)

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# %%
frequent_itemsets.head()
# Out:
#     support       itemsets  length
# 0  0.058973  (frankfurter)       1
# 1  0.093950      (sausage)       1
# 2  0.005084   (liver loaf)       1
# 3  0.026029          (ham)       1
# 4  0.025826         (meat)       1

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.02) ]
# Out:
#        support                     itemsets  length
# 173   0.020539    (whole milk, frankfurter)       2
# 255   0.026945  (other vegetables, sausage)       2
# 257   0.029893        (whole milk, sausage)       2
# 281   0.030605        (rolls/buns, sausage)       2
# 303   0.024301              (soda, sausage)       2
# ...        ...                          ...     ...
# 2387  0.024199  (rolls/buns, bottled water)       2
# 2388  0.038332           (soda, rolls/buns)       2
# 2524  0.021047               (soda, pastry)       2
# 2856  0.028978        (soda, bottled water)       2
# 2928  0.024606        (soda, shopping bags)       2
#
# [61 rows x 3 columns]

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'pastry', 'soda'} ]
# Out:
#        support        itemsets  length
# 2524  0.021047  (soda, pastry)       2

# %%
# %time rules = association_rules(frequent_itemsets, min_threshold=0.1)
# Out:
# Wall time: 302 ms

# %%
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules
# Out:
#                                 antecedents  \
# 0                             (frankfurter)
# 1                                 (sausage)
# 2                                    (meat)
# 3                                    (pork)
# 4                          (hamburger meat)
# ...                                     ...
# 43727  (whole milk, butter, tropical fruit)
# 43728          (whole milk, butter, yogurt)
# 43729      (yogurt, tropical fruit, butter)
# 43730               (domestic eggs, butter)
# 43731              (butter, tropical fruit)
#
#                                              consequents  antecedent support  \
# 0                                              (sausage)            0.058973
# 1                                          (frankfurter)            0.093950
# 2                                          (frankfurter)            0.025826
# 3                                          (frankfurter)            0.057651
# 4                                          (frankfurter)            0.033249
# ...                                                  ...                 ...
# 43727          (other vegetables, yogurt, domestic eggs)            0.006202
# 43728  (other vegetables, tropical fruit, domestic eggs)            0.009354
# 43729      (other vegetables, whole milk, domestic eggs)            0.004575
# 43730  (other vegetables, yogurt, tropical fruit, who...            0.009659
# 43731  (other vegetables, yogurt, whole milk, domesti...            0.009964
#
#        consequent support   support  confidence       lift  leverage  \
# 0                0.093950  0.010066    0.170690   1.816810  0.004526
# 1                0.058973  0.010066    0.107143   1.816810  0.004526
# 2                0.058973  0.003254    0.125984   2.136302  0.001731
# 3                0.058973  0.005897    0.102293   1.734568  0.002497
# 4                0.058973  0.003355    0.100917   1.711246  0.001395
# ...                   ...       ...         ...        ...       ...
# 43727            0.005796  0.001017    0.163934  28.285879  0.000981
# 43728            0.004779  0.001017    0.108696  22.745143  0.000972
# 43729            0.012303  0.001017    0.222222  18.062443  0.000960
# 43730            0.007626  0.001017    0.105263  13.803509  0.000943
# 43731            0.003355  0.001017    0.102041  30.411255  0.000983
#
#        conviction  antecedent_len
# 0        1.092534               1
# 1        1.053950               1
# 2        1.076670               1
# 3        1.048256               1
# 4        1.046652               1
# ...           ...             ...
# 43727    1.189146               3
# 43728    1.116590               3
# 43729    1.269896               3
# 43730    1.109124               2
# 43731    1.109900               2
#
# [43732 rows x 10 columns]

# %%
rules[ (rules['antecedent_len'] >= 2) &
       (rules['confidence'] > 0.75) &
       (rules['lift'] > 1.2) ].sort_values(by="support", ascending=False)
# Out:
#                                              antecedents  \
# 24171    (root vegetables, citrus fruit, tropical fruit)
# 27999                     (yogurt, curd, tropical fruit)
# 38978  (root vegetables, citrus fruit, tropical fruit...
# 30695   (root vegetables, other vegetables, brown bread)
# 31658                  (root vegetables, butter, yogurt)
# ...                                                  ...
# 34392  (other vegetables, long life bakery product, s...
# 34169           (other vegetables, margarine, chocolate)
# 33594  (other vegetables, detergent, whipped/sour cream)
# 32854   (other vegetables, fruit/vegetable juice, herbs)
# 43714    (domestic eggs, yogurt, tropical fruit, butter)
#
#                           consequents  antecedent support  consequent support  \
# 24171              (other vegetables)            0.005694            0.193493
# 27999                    (whole milk)            0.005287            0.255516
# 38978              (other vegetables)            0.003559            0.193493
# 30695                    (whole milk)            0.004067            0.255516
# 31658                    (whole milk)            0.003864            0.255516
# ...                               ...                 ...                 ...
# 34392                    (whole milk)            0.001220            0.255516
# 34169                    (whole milk)            0.001322            0.255516
# 33594                    (whole milk)            0.001220            0.255516
# 32854                    (whole milk)            0.001220            0.255516
# 43714  (other vegetables, whole milk)            0.001322            0.074835
#
#         support  confidence       lift  leverage  conviction  antecedent_len
# 24171  0.004474    0.785714   4.060694  0.003372    3.763701               3
# 27999  0.003965    0.750000   2.935237  0.002614    2.977936               3
# 38978  0.003152    0.885714   4.577509  0.002463    7.056940               4
# 30695  0.003152    0.775000   3.033078  0.002113    3.308818               3
# 31658  0.003050    0.789474   3.089723  0.002063    3.536299               3
# ...         ...         ...        ...       ...         ...             ...
# 34392  0.001017    0.833333   3.261374  0.000705    4.466904               3
# 34169  0.001017    0.769231   3.010499  0.000679    3.226097               3
# 33594  0.001017    0.833333   3.261374  0.000705    4.466904               3
# 32854  0.001017    0.833333   3.261374  0.000705    4.466904               3
# 43714  0.001017    0.769231  10.279055  0.000918    4.009049               4
#
# [758 rows x 10 columns]

# %%
rules[ (rules['antecedents'].apply(lambda x: 'Eggs' in x)) & (rules['antecedent_len'] >=2) ]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, antecedent_len]
# Index: []

# %% [markdown]
# # Exec Ed Slides

# %%
df = pd.read_csv('data/groceries_exec.csv')

df = df.drop(['Date', 'Transaction ID'], axis=1)

df.Items = df.Items.astype(str)
df.Items = df.Items.apply(lambda x: x.split(', '))

te = TransactionEncoder()
te_ary = te.fit(df.Items).transform(df.Items)
df1 = pd.DataFrame(te_ary, columns=te.columns_)
#df1

frequent_itemsets = apriori(df1, min_support=0.06, use_colnames=True)
rules = association_rules(frequent_itemsets, min_threshold=0.1)

rules.sort_values(by="confidence", ascending=False)
# Out:
#                antecedents             consequents  antecedent support  \
# 4          (peanut butter)                 (bacon)                0.25
# 9               (cake mix)                 (beans)                0.20
# 23               (chicken)                (cheese)                0.15
# 22                (cheese)               (chicken)                0.15
# 24               (chicken)                  (milk)                0.15
# 30           (bacon, milk)                 (bread)                0.15
# 34  (bread, peanut butter)                 (bacon)                0.15
# 40           (bread, eggs)                  (milk)                0.15
# 42            (eggs, milk)                 (bread)                0.15
# 26                  (eggs)                  (milk)                0.25
# 15                  (eggs)                 (bread)                0.25
# 19         (peanut butter)                 (bread)                0.25
# 5                  (bacon)         (peanut butter)                0.35
# 1                  (bacon)                 (bread)                0.35
# 36  (peanut butter, bacon)                 (bread)                0.20
# 35          (bread, bacon)         (peanut butter)                0.20
# 20              (cake mix)                  (milk)                0.20
# 29           (bread, milk)                 (bacon)                0.20
# 28          (bread, bacon)                  (milk)                0.20
# 41           (bread, milk)                  (eggs)                0.20
# 0                  (bread)                 (bacon)                0.40
# 16                 (bread)                  (milk)                0.40
# 12                 (beans)                  (milk)                0.30
# 8                  (beans)              (cake mix)                0.30
# 2                  (bacon)                  (milk)                0.35
# 38         (peanut butter)          (bread, bacon)                0.25
# 17                  (milk)                 (bread)                0.50
# 44                  (eggs)           (bread, milk)                0.25
# 10                  (eggs)                 (beans)                0.25
# 14                 (bread)                  (eggs)                0.40
# 18                 (bread)         (peanut butter)                0.40
# 11                 (beans)                  (eggs)                0.30
# 7                  (beans)                 (bread)                0.30
# 27                  (milk)                  (eggs)                0.50
# 13                  (milk)                 (beans)                0.50
# 3                   (milk)                 (bacon)                0.50
# 39                 (bacon)  (bread, peanut butter)                0.35
# 32                 (bacon)           (bread, milk)                0.35
# 37                 (bread)  (peanut butter, bacon)                0.40
# 43                 (bread)            (eggs, milk)                0.40
# 6                  (bread)                 (beans)                0.40
# 31                 (bread)           (bacon, milk)                0.40
# 21                  (milk)              (cake mix)                0.50
# 33                  (milk)          (bread, bacon)                0.50
# 25                  (milk)               (chicken)                0.50
# 45                  (milk)           (bread, eggs)                0.50
#
#     consequent support  support  confidence      lift  leverage  conviction
# 4                 0.35     0.20    0.800000  2.285714    0.1125    3.250000
# 9                 0.30     0.15    0.750000  2.500000    0.0900    2.800000
# 23                0.15     0.10    0.666667  4.444444    0.0775    2.550000
# 22                0.15     0.10    0.666667  4.444444    0.0775    2.550000
# 24                0.50     0.10    0.666667  1.333333    0.0250    1.500000
# 30                0.40     0.10    0.666667  1.666667    0.0400    1.800000
# 34                0.35     0.10    0.666667  1.904762    0.0475    1.950000
# 40                0.50     0.10    0.666667  1.333333    0.0250    1.500000
# 42                0.40     0.10    0.666667  1.666667    0.0400    1.800000
# 26                0.50     0.15    0.600000  1.200000    0.0250    1.250000
# 15                0.40     0.15    0.600000  1.500000    0.0500    1.500000
# 19                0.40     0.15    0.600000  1.500000    0.0500    1.500000
# 5                 0.25     0.20    0.571429  2.285714    0.1125    1.750000
# 1                 0.40     0.20    0.571429  1.428571    0.0600    1.400000
# 36                0.40     0.10    0.500000  1.250000    0.0200    1.200000
# 35                0.25     0.10    0.500000  2.000000    0.0500    1.500000
# 20                0.50     0.10    0.500000  1.000000    0.0000    1.000000
# 29                0.35     0.10    0.500000  1.428571    0.0300    1.300000
# 28                0.50     0.10    0.500000  1.000000    0.0000    1.000000
# 41                0.25     0.10    0.500000  2.000000    0.0500    1.500000
# 0                 0.35     0.20    0.500000  1.428571    0.0600    1.300000
# 16                0.50     0.20    0.500000  1.000000    0.0000    1.000000
# 12                0.50     0.15    0.500000  1.000000    0.0000    1.000000
# 8                 0.20     0.15    0.500000  2.500000    0.0900    1.600000
# 2                 0.50     0.15    0.428571  0.857143   -0.0250    0.875000
# 38                0.20     0.10    0.400000  2.000000    0.0500    1.333333
# 17                0.40     0.20    0.400000  1.000000    0.0000    1.000000
# 44                0.20     0.10    0.400000  2.000000    0.0500    1.333333
# 10                0.30     0.10    0.400000  1.333333    0.0250    1.166667
# 14                0.25     0.15    0.375000  1.500000    0.0500    1.200000
# 18                0.25     0.15    0.375000  1.500000    0.0500    1.200000
# 11                0.25     0.10    0.333333  1.333333    0.0250    1.125000
# 7                 0.40     0.10    0.333333  0.833333   -0.0200    0.900000
# 27                0.25     0.15    0.300000  1.200000    0.0250    1.071429
# 13                0.30     0.15    0.300000  1.000000    0.0000    1.000000
# 3                 0.35     0.15    0.300000  0.857143   -0.0250    0.928571
# 39                0.15     0.10    0.285714  1.904762    0.0475    1.190000
# 32                0.20     0.10    0.285714  1.428571    0.0300    1.120000
# 37                0.20     0.10    0.250000  1.250000    0.0200    1.066667
# 43                0.15     0.10    0.250000  1.666667    0.0400    1.133333
# 6                 0.30     0.10    0.250000  0.833333   -0.0200    0.933333
# 31                0.15     0.10    0.250000  1.666667    0.0400    1.133333
# 21                0.20     0.10    0.200000  1.000000    0.0000    1.000000
# 33                0.20     0.10    0.200000  1.000000    0.0000    1.000000
# 25                0.15     0.10    0.200000  1.333333    0.0250    1.062500
# 45                0.15     0.10    0.200000  1.333333    0.0250    1.062500

# %%
df1.loc[df1['cake mix'] == True]
# Out:
#     apple  bacon  banana  beans  bread  cake mix  carrot  cheese  chicken  \
# 9   False  False   False   True  False      True   False   False    False
# 13  False  False   False   True   True      True   False   False    False
# 15  False  False   False   True  False      True   False   False    False
# 17  False  False   False  False  False      True   False   False    False
#
#      eggs  ice cream   milk  peanut butter
# 9   False      False   True          False
# 13  False      False  False           True
# 15  False       True  False          False
# 17  False      False   True          False

# %%
df1.loc[df1['peanut butter'] == True]
# Out:
#     apple  bacon  banana  beans  bread  cake mix  carrot  cheese  chicken  \
# 1   False   True   False  False  False     False   False   False    False
# 3   False   True   False  False   True     False   False   False    False
# 13  False  False   False   True   True      True   False   False    False
# 16  False   True   False  False  False     False   False   False    False
# 18  False   True   False  False   True     False   False   False    False
#
#      eggs  ice cream   milk  peanut butter
# 1   False      False  False           True
# 3   False      False  False           True
# 13  False      False  False           True
# 16  False      False  False           True
# 18  False      False   True           True

# %%
df1.loc[df1['chicken'] == True]
# Out:
#     apple  bacon  banana  beans  bread  cake mix  carrot  cheese  chicken  \
# 2   False  False   False  False  False     False    True    True     True
# 4   False   True   False  False  False     False   False   False     True
# 10  False  False   False   True  False     False   False    True     True
#
#      eggs  ice cream   milk  peanut butter
# 2   False      False   True          False
# 4   False      False   True          False
# 10   True      False  False          False

# %%
df1.loc[df1['peanut butter'] == True]
# Out:
#     apple  bacon  banana  beans  bread  cake mix  carrot  cheese  chicken  \
# 1   False   True   False  False  False     False   False   False    False
# 3   False   True   False  False   True     False   False   False    False
# 13  False  False   False   True   True      True   False   False    False
# 16  False   True   False  False  False     False   False   False    False
# 18  False   True   False  False   True     False   False   False    False
#
#      eggs  ice cream   milk  peanut butter
# 1   False      False  False           True
# 3   False      False  False           True
# 13  False      False  False           True
# 16  False      False  False           True
# 18  False      False   True           True
